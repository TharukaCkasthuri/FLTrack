# %%
import torch

from torch.utils.data import DataLoader

from models import ShallowNN
from utils import evaluate

# %%
#baseline training
baseline_model = ShallowNN(197)

# %%
baseline_model.load_state_dict(torch.load("checkpt/_128_baseline.pth"))
# Out:
# <All keys matched successfully>

# %%
for param_tensor in baseline_model.state_dict():
    print(param_tensor, "\t", baseline_model.state_dict()[param_tensor].size())
# Out:
# layer_1.weight 	 torch.Size([64, 197])
# layer_1.bias 	 torch.Size([64])
# layer_2.weight 	 torch.Size([32, 64])
# layer_2.bias 	 torch.Size([32])
# layer_3.weight 	 torch.Size([1, 32])
# layer_3.bias 	 torch.Size([1])

# %%
baseline_model.eval()
# Out:
# ShallowNN(
#   (layer_1): Linear(in_features=197, out_features=64, bias=True)
#   (relu_1): ReLU()
#   (layer_2): Linear(in_features=64, out_features=32, bias=True)
#   (relu_2): ReLU()
#   (layer_3): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
test_dataset_1 = torch.load('testpt/0_2.pt')

# %%
test_dl_1 = DataLoader(test_dataset_1, 128, shuffle=True)

# %%
loss_fn = torch.nn.MSELoss()

# %%
evaluate(baseline_model, test_dl_1, loss_fn)
# Out:
# (0.7162975801361932, 0.7162975845119309, 0.3021118489522783)

# %%
import os 

import pandas as pd
import numpy as np
import seaborn as sns

from utils import load_file

# %%
data_path = "../kv_data/kv/"

# %%
data_path = "../kv_data/kv/"
files = os.listdir(data_path)
ids = [file.split(".")[0] for file in files]
files_path = [os.path.join(data_path, file) for file in files]

# %%
data_frame = load_file(files_path[3])

# %%
sns.boxplot(data=data_frame)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig,axes = plt.subplots(nrows=4,ncols=6,figsize=(60, 30))
pd.read_csv("../Results/0_0.csv").plot(ax=axes[0][0],title='0_0')
pd.read_csv("../Results/0_1.csv").plot(ax=axes[0][1],title='0_1')
pd.read_csv("../Results/0_2.csv").plot(ax=axes[0][2],title='0_2')
pd.read_csv("../Results/0_3.csv").plot(ax=axes[0][3],title='0_3')
pd.read_csv("../Results/0_4.csv").plot(ax=axes[0][4],title='0_4')
pd.read_csv("../Results/0_5.csv").plot(ax=axes[0][5],title='0_5')
pd.read_csv("../Results/1_0.csv").plot(ax=axes[1][0],title='1_0')
pd.read_csv("../Results/1_1.csv").plot(ax=axes[1][1],title='1_1')
pd.read_csv("../Results/1_2.csv").plot(ax=axes[1][2],title='1_2')
pd.read_csv("../Results/1_3.csv").plot(ax=axes[1][3],title='1_3')
pd.read_csv("../Results/1_4.csv").plot(ax=axes[1][4],title='1_4')
pd.read_csv("../Results/1_5.csv").plot(ax=axes[1][5],title='1_5')
pd.read_csv("../Results/2_0.csv").plot(ax=axes[2][0],title='2_0')
pd.read_csv("../Results/2_1.csv").plot(ax=axes[2][1],title='2_1')
pd.read_csv("../Results/2_2.csv").plot(ax=axes[2][2],title='2_2')
pd.read_csv("../Results/2_3.csv").plot(ax=axes[2][3],title='2_3')
pd.read_csv("../Results/2_4.csv").plot(ax=axes[2][4],title='2_4')
pd.read_csv("../Results/2_5.csv").plot(ax=axes[2][5],title='2_5')
pd.read_csv("../Results/3_0.csv").plot(ax=axes[3][0],title='3_0')
pd.read_csv("../Results/3_1.csv").plot(ax=axes[3][1],title='3_1')
pd.read_csv("../Results/3_2.csv").plot(ax=axes[3][2],title='3_2')
pd.read_csv("../Results/3_3.csv").plot(ax=axes[3][3],title='3_3')
pd.read_csv("../Results/3_4.csv").plot(ax=axes[3][4],title='3_4')
pd.read_csv("../Results/3_5.csv").plot(ax=axes[3][5],title='3_5')
# Out:
# <Axes: title={'center': '3_5'}>

# %%
pd.read_csv("../Results/0_0.csv").plot(ax=axes[0][0])
# Out:
# <Axes: >
